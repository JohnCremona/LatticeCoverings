# %%
# %runfile congruences.sage

# %%
for n in [1..5]:
    print(minimal_coverings(n))
    print("---------------------------------")
# Out:
# Finding all minimal covering congruences of size 1
# The only covering congruence of size 1 is the trivial one
# All 1 minimal coverings found are strongly minimal.
# [[<0;1>]]
# ---------------------------------
# Finding all minimal covering congruences of size 2
# New covering # 1: [<0;2>, <1;2>]  (strongly minimal)
# New modulus pattern # 1: [2, 2], weight = 1 (strongly minimal)
# FindCovering() finds 1 of size 2 after recursion to depth 1
#  --used 4 primitive integers of modulus up to 3 :
# [0, 1, 2, 3]
# 1 different modulus patterns occur
# All 1 minimal coverings found are strongly minimal.
# [[<0;2>, <1;2>]]
# ---------------------------------
# Finding all minimal covering congruences of size 3
# New covering # 1: [<0;2>, <1;4>, <3;4>]  (strongly minimal)
# New modulus pattern # 1: [2, 4, 4], weight = 1 (strongly minimal)
# New covering # 2: [<0;3>, <1;3>, <2;3>]  (strongly minimal)
# New modulus pattern # 2: [3, 3, 3], weight = 1 (strongly minimal)
# ...
