# %%
# %runfile coverings.sage

# %% [markdown]
# #### minimal coverings of size 7:

# %%
time mc7 = minimal_coverings(7)
# Out:
# Finding all minimal lattice coverings of size 7
# New index pattern # 1: (2, 2, 4, 8, 16, 32, 32), weight = 1 (strongly minimal)
# New index pattern # 2: (2, 2, 4, 16, 16, 16, 16), weight = 1 (strongly minimal)
# New index pattern # 3: (2, 2, 4, 12, 12, 12, 12), weight = 1 (strongly minimal)
# New index pattern # 4: (2, 2, 8, 8, 8, 16, 16), weight = 1 (strongly minimal)
# New index pattern # 5: (2, 2, 6, 6, 6, 12, 12), weight = 1 (strongly minimal)
# New index pattern # 6: (2, 4, 4, 4, 8, 16, 16), weight = 1 (strongly minimal)
# New index pattern # 7: (2, 4, 4, 8, 8, 8, 8), weight = 1 (strongly minimal)
# New index pattern # 8: (2, 4, 4, 6, 6, 6, 6), weight = 1 (strongly minimal)
# New index pattern # 9: (2, 3, 3, 6, 6, 6, 6), weight = 7/6
# New index pattern # 10: (3, 3, 3, 6, 6, 12, 12), weight = 1 (strongly minimal)
# New index pattern # 11: (4, 4, 4, 4, 4, 8, 8), weight = 1 (strongly minimal)
# FindLattice() finds 144 of size 7 after recursion to depth 16
# ...

# %%
mc7
# Out:
# [[L(1:0;2), L(1:1;2), L(2:1;4), L(4:1;8), L(8:1;16), L(0:1;32), L(16:1;32)],
#  [L(1:0;2), L(1:1;2), L(2:1;4), L(4:1;8), L(0:1;16), L(8:1;32), L(8:3;32)],
#  [L(1:0;2), L(1:1;2), L(2:1;4), L(0:1;16), L(4:1;16), L(4:3;16), L(8:1;16)],
#  [L(1:0;2), L(1:1;2), L(2:1;4), L(0:1;8), L(4:3;16), L(4:1;32), L(4:5;32)],
#  [L(1:0;2), L(1:1;2), L(2:1;4), L(0:1;8), L(4:1;16), L(4:3;32), L(4:7;32)],
#  [L(1:0;2), L(1:1;2), L(2:1;4), L(0:1;12), L(4:1;12), L(4:3;12), L(4:5;12)],
#  [L(1:0;2), L(1:1;2), L(2:1;8), L(2:3;8), L(4:1;8), L(0:1;16), L(8:1;16)],
#  [L(1:0;2), L(1:1;2), L(0:1;8), L(2:1;8), L(2:3;8), L(4:1;16), L(4:3;16)],
#  [L(1:0;2), L(1:1;2), L(0:1;4), L(2:3;8), L(2:5;16), L(2:1;32), L(2:9;32)],
#  [L(1:0;2), L(1:1;2), L(0:1;4), L(2:3;8), L(2:1;16), L(2:5;32), L(2:13;32)],
#  [L(1:0;2), L(1:1;2), L(0:1;8), L(2:3;8), L(4:1;8), L(2:1;16), L(2:5;16)],
#  [L(1:0;2), L(1:1;2), L(0:1;4), L(2:1;8), L(2:3;16), L(2:7;32), L(2:15;32)],
# ...
