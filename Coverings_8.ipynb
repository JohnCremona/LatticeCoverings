# %%
# %runfile lattices.sage

# %% [markdown]
# #### All minimal coverings of size 8:

# %%
time mc8 = minimal_coverings(8)
# Out:
# New index pattern # 1: (2, 2, 4, 8, 16, 32, 64, 64), weight = 1 (strongly minimal)
# New index pattern # 2: (2, 2, 4, 8, 32, 32, 32, 32), weight = 1 (strongly minimal)
# New index pattern # 3: (2, 2, 4, 8, 24, 24, 24, 24), weight = 1 (strongly minimal)
# New index pattern # 4: (2, 2, 4, 16, 16, 16, 32, 32), weight = 1 (strongly minimal)
# New index pattern # 5: (2, 2, 4, 12, 12, 12, 24, 24), weight = 1 (strongly minimal)
# New index pattern # 6: (2, 2, 8, 8, 8, 16, 32, 32), weight = 1 (strongly minimal)
# New index pattern # 7: (2, 2, 8, 8, 16, 16, 16, 16), weight = 1 (strongly minimal)
# New index pattern # 8: (2, 2, 8, 8, 12, 12, 12, 12), weight = 1 (strongly minimal)
# New index pattern # 9: (2, 2, 6, 6, 6, 12, 24, 24), weight = 1 (strongly minimal)
# New index pattern # 10: (2, 2, 6, 6, 6, 18, 18, 18), weight = 1 (strongly minimal)
# New index pattern # 11: (2, 2, 6, 6, 12, 12, 12, 12), weight = 1 (strongly minimal)
# ...
